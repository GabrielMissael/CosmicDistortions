# %% [markdown]
# # Visión computacional
# *Notebook hecho por Zaid De Anda y Missael Barco 🚢*

# %% [markdown]
# Recordemos que las imágenes son matrices, entonces empecemos a crear imágenes desde cero!
#
# NOTA: Todos los problemas se pueden hacer con numpy y con listas. Recomiendo mucho inicializar la imagen con numpy y trabajar todo con ciclos

# %%
import numpy as np
from google.colab.patches import cv2_imshow

#TODO
#Crear un recuadro negro de 100x100

# %%
#TODO
#Pintarle una franja blanca a la mitad horizontalmente

# %%
#TODO
#Pintarle una franja gris a la mitad verticalmente

# %% [markdown]
# ¿Ya notaron que nuestro arreglo es solo de dos dimensiones?
#
# Ahora experimentemos con tres dimensiones!

# %%
#TODO
#Crear una imagen azul

# %% [markdown]
# ### Nota histórica sobre BGR!

# %%
#TODO
#Crear una imagen amarilla

# %% [markdown]
# ## Juguemos con las capas de color de una imagen

# %%
# !wget https://raw.githubusercontent.com/GabrielMissael/CosmicDistortions/refs/heads/day1/Assets/Lechuga.jpeg
# !wget https://raw.githubusercontent.com/GabrielMissael/CosmicDistortions/refs/heads/day1/Assets/Panque.jpeg
# Out:
# --2025-07-21 22:48:34--  https://raw.githubusercontent.com/GabrielMissael/CosmicDistortions/refs/heads/day1/Assets/Lechuga.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1151226 (1.1M) [image/jpeg]
# Saving to: ‘Lechuga.jpeg’
#
# Lechuga.jpeg        100%[===================>]   1.10M  --.-KB/s    in 0.06s
#
# 2025-07-21 22:48:34 (17.2 MB/s) - ‘Lechuga.jpeg’ saved [1151226/1151226]
#
# --2025-07-21 22:48:34--  https://raw.githubusercontent.com/GabrielMissael/CosmicDistortions/refs/heads/day1/Assets/Panque.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %% [markdown]
# También si quieres hacerlo con tu propia imagen...

# %%
from google.colab import files

uploaded = files.upload()

# %%
import cv2

cat_image = cv2.imread('/content/Lechuga.jpeg', cv2.IMREAD_GRAYSCALE)
cat_image = cv2.resize(cat_image, [750,1000])
cv2_imshow(cat_image)
# Out:
# <PIL.Image.Image image mode=L size=750x1000>

# %%
#TODO
#Pinta a un gato de verde

# %%
#TODO
#Ponle ojos rojos al gato

# %% [markdown]
# ## Procesamiento digital de imágenes

# %%
#TODO
#Teniendo un gato blanco y negro, binariza la imagen
#Ahora usa un promedio de pixeles en la imagen para la binarización

# %%
cat_image_2 = cv2.imread('/content/Lechuga.jpeg')

# %%
import matplotlib.pyplot as plt

_, axs = plt.subplots(1, 2, figsize=(12, 12))
imgs = [cat_image, cat_image_2]
for img, ax in zip(imgs, axs):
    ax.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# ## Kernels y convoluciones!

# %%
import numpy as np
from scipy.signal import convolve2d, correlate2d

#TODO
#Hacer una convolución sencilla a mano y con scipy

# %%
#TODO
#Crear una función para dado un kernel, pasarle el filtro por toda la imagen (convolución)

# %% [markdown]
# Este es el kernel de la matriz para detección de ejes
#
# \begin{bmatrix}-1&-1&-1\\-1&\ \ 8&-1\\-1&-1&-1\end{bmatrix}

# %% [markdown]
# Este es el kernel de la matriz para hacer sharpen
#
# \begin{bmatrix}0&-1&0\\-1&\ \ 5&-1\\0&-1&0\end{bmatrix}

# %%
#TODO
#Experimentar con filtros verticales, horizontales, etc

# %% [markdown]
# ## Reto
#
# Hacer kernels sobre las 3 imágenes. Podriamos procesar las 3 capas a la vez, o hacerlo por separado
