# %% [markdown]
# # Día 2 Curso de Python para clubes de ciencia
# *notebook hecho por Zaid De Anda y Missael Barco 🚢*
#
# Ayer vimos:
# * Variables
# * Operaciones lógicas
# * Colecciones de datos
# * como interactuar con listas
#
# El día de hoy veremos como interactuar de una forma más spicy 🌶

# %% [markdown]
# # Control de flujo (condicionales)
#
# Hasta ahora todo nuestro código ha ejecutado secuencialmente, de un paso a otro. ¿Qué pasaría si quisiera tener dos casos de código? Un bloque para cuando pase A, y otro para cuando pase B. Para eso se usa el control de flujo
#
# Podemos empezar con la sentencia if, se escribe de la siguiente forma
#
# ```
# if <condicion>:
#   sentencia
# else:
# sentencia
# ```
#
# Ojo con la indentación!

# %%
#TODO
#Pregunta tu edad, revisa si es mayor de 18

# %% [markdown]
# ¿Qué pasa si queremos dos ifs al mismo nivel? usamos `elif`

# %%
#TODO
#Preguntar sobre el clima

# %% [markdown]
# Y si queremos un if... dentro de otro if?

# %%
#TODO
#Usar nested ifs para preguntar color y si te gusta

# %% [markdown]
# #Ciclos!
#
# Ahora, que pasa si queremos repetir una sentencia varias veces mientras pase algo?
#
# Usamos la sentencia `for`, la sintáxis es:
#
#
#
# ```python
# for <elemento> in <fuente>:
#   sentencia
# ```
#
# Empezamos poniendo listas e imprimiendo sus elementos. El ciclo `for` es muy diferente en otros lenguajes, pero podemos hacer que funcione también en su respectiva forma. Haremos versión del for tradicional y la versión de python

# %%
#TODO
#Iterar una lista de una forma como C con enumerate

# %%
#TODO
#Hacer una lista de numeros e iterarla en la versión pythonic

# %% [markdown]
# ¿Y qué tal... iterando una lista de listas?

# %%
#TODO
#Iterar una lista de listas como lo hiciera C

# %%
#TODO
#Iterar una lista de listas como si lo hiciera python

# %% [markdown]
# # Funciones
#
# A veces, queremos repetir un código mas de una vez, y copiarlo y pegarlo se vuelve un poco pesado. Para ello, definiremos nuestras propias funciones! Una función puede tomar varios argumentos para hacer algo con ellos, y retornar algo nuevo

# %%
#TODO
#Hacer una función que solo imprima un nombre

# %% [markdown]
# #Librerias
#
# Mientras trabajamos en python, podemos importar librerías o frameworks. Estos son repositorios de código que incluyen funciones que nos pueden ayudar a trabajar mucho con ciertos tipos de datos, como numpy.
#
# hay librerías que nos ayudan de forma simple y otras que involucran su propia forma de trabajar, a esas últimas les llamamos frameworks. Un framework que veremos y trabajaremos será numpy!

# %% [markdown]
# numpy presenta sus propios array, llamados numpy arrays (jeje) y destacan en trabajar con datos homogeneos (con el mismo tipo de variable) y forma rectangular

# %%
#TODO
#Declara un numpy array

# %% [markdown]
# Los np arrays tienen funciones muy cool, por ejemplo, que pasa si queremos sumarle 2 a todo el array?

# %%
#TODO
#sumarle 2 a una lista de listas

# %%
#TODO
#Ahora hacer lo mismo con un np array

# %% [markdown]
# Hay una diferencia: cuando haces slice a una lista, se crea una nueva copia de la lista. Cuando haces slice de un np array, se crea una vista del dicho

# %%
#TODO
#Crear un np array, crear un slice de el, modificarlo y observar que ocurre

# %% [markdown]
# ### Indexación
#
# Para indexar arrays multidimensionales, ya no tienes que separar los argumentos con corchetes como con listas, todo puede estar en el mismo elemento pero separado por comas

# %%
#TODO
#Hacer multi indexación con listas

# %%
#TODO
#Hacer multi indexación con np arrays

# %% [markdown]
# También podemos crearlas de forma muy sencilla!

# %%
#TODO
#mostrar np.zeros y np.ones

# %% [markdown]
# Y unirlos tambiém

# %%
#TODO
#Mostrar np.concatenate para concatenar arreglos, primero en axis=0 y luego axis=1
